# %%
# !nvidia-smi

# %%
# !pip install ultralytics

# %% [markdown]
# #Ola

# %%
# !unzip "/content/Dataset_1.zip" -d "/content/Dataset_1"

# %%
# https://github.com/ultralytics/ultralytics/blob/main/examples/tutorial.ipynb
# https://github.com/entbappy/YOLO-v8-Object-Detection/blob/main/Yolov8_object_detection_on_custom_dataset.ipynb

from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch

# Use the model
results = model.train(data='config.yaml', imgsz=640, epochs=1, name='yolov8n_custom')

# %%
# !yolo task=detect mode=train model=yolov8s.pt data='config.yaml' epochs=10 imgsz=640 plots=True

# %%
import os
path = '/content/dataset/tjoint_0/labels/train2023'
files = os.listdir(path)
for file in files:
  #print(file.replace('Label','Image'))
  os.rename(os.path.join(path, file), os.path.join(path, file.replace('Label','Image')))

# %%
# !ls runs/detect/train/

# %%
from IPython.display import display, Image

#Image(filename='runs/detect/train/confusion_matrix.png', width=600)
#Image(filename='runs/detect/train/results.png', width=600)

# %%
# export to onnx
from ultralytics import YOLO

model = YOLO("yolov8s.pt")  
model.export(format="onnx",opset=12)  # export the model to ONNX format

# %%
# !yolo predict model='/content/runs/detect/train5/weights/best.pt' source='/content/Image_00001.png' imgsz=640
